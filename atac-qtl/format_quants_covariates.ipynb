# %% [markdown]
# ## Notebook that pulls together known subject and sample covariates cleans up as neccessary and writes to single file

# %%
# !date
# Out:
# Mon Aug  2 04:20:25 UTC 2021

# %% [markdown]
# #### import libraries and set notebook variables

# %%
import pandas as pd
import ppscore as pps
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
# parameter variables
cohort = 'foundin'

# directories 
wrk_dir = f'/home/jupyter/caqtl'
info_dir = f'{wrk_dir}/sample_info'

# input files
src_info_bckt_path = 'gs://foundin-processed-assay/analysis/integration/sample_info'
subject_info_file = f'{src_info_bckt_path}/amppd_demographicsPlus_2019_v1release_1015.csv'
cell_info_file = f'{src_info_bckt_path}/cell_metadata.csv'
genos_pca_file = f'{src_info_bckt_path}/foundin.freeze9.pca.eigenvec'
cell_fracs_file = f'{src_info_bckt_path}/rnab_cell_fracs_scaden.csv'
assay_metrics_file = f'{src_info_bckt_path}/foundin_atac_metrics.csv'
subj_overview_file = f'{src_info_bckt_path}/Expanded_overview_of_included_PPMI_samples_overview.csv'
subj_grs_file = f'{src_info_bckt_path}/Expanded_overview_of_included_PPMI_samples_GRS.csv'

# output files
assay_covs_files = f'{info_dir}/{cohort}_atac_sample_info.csv'

# constants
max_cov_missing_rate = 0.5
repeated_id_dict = {'PPMI3966B1': 'PPMI3966', 'PPMI3966B2': 'PPMI3966', 
                    'PPMI3966B3': 'PPMI3966', 'PPMI3966B5': 'PPMI3966'}

# %% [markdown]
# #### load cell line info

# %%
cell_info = pd.read_csv(cell_info_file)
print(cell_info.shape)
# add 'PPMI' to patno
cell_info['PPMI_ID'] = 'PPMI' + cell_info['PPMI_ID'].astype(str)
# display(cell_info.sample(10))
# Out:
# (101, 15)

# %% [markdown]
# #### load subject info file, from AMP-PD, and merge with cell info

# %%
subj_info = pd.read_csv(subject_info_file)
subj_info['wgsid'] = subj_info['participant_id']
subj_info['participant_id'] = subj_info['participant_id'].str.replace('PP-', 'PPMI')
print(subj_info.shape)
# display(subj_info.head())

# now merge cell and subject info
info_df = pd.merge(cell_info, subj_info, how='left', left_on='PPMI_ID', right_on='participant_id')
print(info_df.shape)
# display(info_df.head())
# Out:
# (4298, 17)
# (101, 32)

# %% [markdown]
# #### load the FOUNDIN subject overiew files and merge

# %%
overview_df = pd.read_csv(subj_overview_file)
overview_df['PPMI_ID'] = 'PPMI' + overview_df['PATNO'].astype(str)
print(overview_df.shape)
# display(overview_df.head())
# Out:
# (135, 24)

# %%
grs_df = pd.read_csv(subj_grs_file)
grs_df['PPMI_ID'] = grs_df['IID'].str.replace('PPMISI', 'PPMI')
print(grs_df.shape)
# display(grs_df.head())
# Out:
# (127, 13)

# %%
# these originated from same file, think they have duplicated columns
print(set(overview_df.columns) & set(grs_df.columns))
display(overview_df.info())
display(grs_df.info())
# Out:
# {'exclude', 'IID', 'PPMI_ID', 'DESCRP_CAT', 'RECRUITMENT_CAT'}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PATNO            135 non-null    int64
#  1   RECRUIT          135 non-null    object
#  2   YEARSEDUC        135 non-null    int64
#  3   FAMILY_HISTORY   134 non-null    float64
#  4   DX_INIT          135 non-null    object
#  5   DIAG             135 non-null    object
#  6   AGE_enroll       135 non-null    float64
#  7   AGE_ONSET        73 non-null     float64
#  8   BIRTHDT          135 non-null    int64
#  9   RECRUITMENT_CAT  135 non-null    object
#  10  IMAGING_CAT      135 non-null    object
#  11  ENROLL_CAT       135 non-null    object
#  12  DESCRP_CAT       83 non-null     object
#  13  genetic_sex      134 non-null    float64
#  14  pheno            135 non-null    object
#  15  Barcode_LNG      135 non-null    object
#  16  Barcode_DZNE     135 non-null    object
#  17  Alternate MRN    135 non-null    object
#  18  IID              135 non-null    object
#  19  mutation         75 non-null     object
#  20  ethnicity        135 non-null    object
#  21  Relatives        12 non-null     object
#  22  exclude          18 non-null     object
#  23  PPMI_ID          135 non-null    object
# dtypes: float64(4), int64(3), object(17)
# memory usage: 25.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FID              127 non-null    object
#  1   IID              127 non-null    object
#  2   RECRUITMENT_CAT  127 non-null    object
#  3   DESCRP_CAT       80 non-null     object
#  4   PHENO            127 non-null    int64
#  5   CNT              127 non-null    int64
#  6   CNT2             127 non-null    int64
#  7   SCORE            127 non-null    float64
#  8   SCORE_no_GBA     127 non-null    float64
#  9   exclude          13 non-null     object
#  10  NOTE             4 non-null      object
#  11  GROUP            127 non-null    object
#  12  PPMI_ID          127 non-null    object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 13.0+ KB
# None

# %%
cols_to_drop = ['RECRUITMENT_CAT', 'exclude', 'DESCRP_CAT', 'IID', 'IID', 
                'PHENO', 'NOTE']
grs_df.drop(columns=cols_to_drop, inplace=True)

# %%
# couple of the categoricals look like they have decent amount of missing
check_these_columns = ['DESCRP_CAT', 'mutation', 'Relatives', 'exclude']

for this_col in check_these_columns:
    print(this_col)
    print(overview_df[this_col].value_counts())
# Out:
# DESCRP_CAT
# LRRK2+    37
# GBA+      34
# HYP        5
# SNCA+      4
# RBD        3
# Name: DESCRP_CAT, dtype: int64
# mutation
# LRRK2_G2019S              35
# GBA_N409S                 33
# SNCA_A53T                  4
# LRRK2_G2019S_GBA_N409S     2
# LRRK2_Arg1441Gly           1
# Name: mutation, dtype: int64
# Relatives
# first_degree_with_50860    1
# first_degree_with_50219    1
# first_degree_with_50184    1
# first_degree_with_40273    1
# first_degree_with_52787    1
# first_degree_with_52783    1
# first_degree_with_53340    1
# first_degree_with_53339    1
# first_degree_with_54265    1
# first_degree_with_54262    1
# first_degree_with_57170    1
# first_degree_with_56169    1
# Name: Relatives, dtype: int64
# exclude
# YES, ancestry                           6
# relative_exclude                        5
# YES, not 100% concordance               3
# YES, not PD                             2
# YES, ancestry + not 100% concordance    1
# YES, no genome                          1
# Name: exclude, dtype: int64

# %%
# so those missing can be filled with None category instead of missing
for this_col in check_these_columns:
    overview_df[this_col].fillna('None', inplace=True)

# %%
# merge overview and grs
overview_df = overview_df.merge(grs_df, how='left', on='PPMI_ID')
print(overview_df.shape)
# display(overview_df.sample(5))
# Out:
# (135, 30)

# %%
# merge with large info
info_df = info_df.merge(overview_df, how='left', on='PPMI_ID')
print(info_df.shape)
# display(info_df.sample(5))
# Out:
# (101, 61)

# %% [markdown]
# #### load and merge in the genetics PCs

# %%
genetic_components_df = pd.read_csv(genos_pca_file, sep='\s+', index_col=1)
genetic_components_df.drop(columns=['#FID'], inplace=True)
print(genetic_components_df.shape)

# merge genetics PCs with other info
info_df = info_df.merge(genetic_components_df, how='left', left_on='wgsid', right_index=True)
print(info_df.shape)
# display(info_df.head())
# Out:
# (133, 20)
# (101, 81)

# %% [markdown]
# #### load the sample assays metrics info

# %%
# load the sample QC info
metrics_info = pd.read_csv(assay_metrics_file, index_col=0)
print(metrics_info.shape)
# display(metrics_info.head())
# Out:
# (290, 1)

# %% [markdown]
# #### split sample name index into constituent bits

# %%
col_names = ['assay', 'sampleid', 'cdi', 'day', 'version']
id_parts = metrics_info.index.str.split('_', expand=True).to_frame(index=False, name=col_names)
id_parts['assayid'] = id_parts['assay'] + '_' + id_parts['sampleid'] + '_' + id_parts['day']
print(id_parts.shape)
# fix sampleid for repeated sample 
id_parts['sampleid'].replace(repeated_id_dict, inplace=True)
# display(id_parts.sample(5))
# Out:
# (290, 6)

# %% [markdown]
# #### get counts by day

# %%
id_parts['day'].value_counts()
# Out:
# da0     99
# da25    97
# da65    94
# Name: day, dtype: int64

# %% [markdown]
# #### merge the split assay IDs bits onto the other info

# %%
info_df = id_parts.merge(info_df, how='left', left_on='sampleid', right_on='PPMI_ID')
info_df.drop_duplicates(subset=['assayid'], inplace=True)
info_df.set_index('assayid', drop=True, inplace=True)
print(info_df.shape)
# display(info_df.head())
# Out:
# (290, 86)

# %% [markdown]
# #### now merge the assay QC/metrics with rest of info by assay's sample id

# %%
info_df = info_df.merge(metrics_info, how='left', left_index=True, right_index=True)
print(info_df.shape)
# display(info_df.head())
# Out:
# (290, 87)

# %% [markdown]
# #### load the cell fractions and merge with other info

# %%
cfracs_df = pd.read_csv(cell_fracs_file, index_col=0)
# replace the assay type, using RNAB estimated fractions for other assays as well.
cfracs_df.index = cfracs_df.index.str.replace('RNAB_', 'ATAC_')
# now clean up assay ids
col_names = ['assay', 'sampleid', 'cdi', 'day', 'version']
id_parts = cfracs_df.index.str.split('_', expand=True).to_frame(index=False, name=col_names)
id_parts['assayid'] = id_parts['assay'] + '_' + id_parts['sampleid'] + '_' + id_parts['day']
print(id_parts.shape)
# fix sampleid for repeated sample 
id_parts['sampleid'].replace(repeated_id_dict, inplace=True)
# display(id_parts.head())

cfracs_df.index = id_parts['assayid']
print(cfracs_df.shape)
# display(cfracs_df.head())

info_df = info_df.merge(cfracs_df, how='left', left_index=True, right_index=True)
print(info_df.shape)
# display(info_df.head())
# Out:
# (301, 6)
# (301, 7)
# (298, 94)

# %% [markdown]
# #### check the dtypes and fix as neccessary

# %%
pd.set_option('display.max_rows', None)
# display(info_df.dtypes)
display(info_df.info())
pd.reset_option('display.max_rows')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, ATAC_PPMI18567_da0 to ATAC_PPMI90456_da65
# Data columns (total 94 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   assay                               298 non-null    object
#  1   sampleid                            298 non-null    object
#  2   cdi                                 298 non-null    object
#  3   day                                 298 non-null    object
#  4   version                             298 non-null    object
#  5   Batch                               292 non-null    object
#  6   PPMI_ID                             292 non-null    object
#  7   DZNE_Barcode                        292 non-null    object
#  8   DZNE_ID                             292 non-null    object
#  9   Culture_Media_iPSC                  292 non-null    object
#  10  Growth_iPSC                         292 non-null    object
#  11  Spontaneous_differentiation         292 non-null    object
#  12  Mychoplasma_Test                    292 non-null    object
#  13  Differentiation_Start               292 non-null    object
#  14  TH_SCRN                             249 non-null    float64
#  15  MAP2_SCRN                           249 non-null    float64
#  16  TH_Pel-Freez_ICC                    285 non-null    float64
#  17  MAP2_Santa_Cruz_ICC                 285 non-null    float64
#  18  TH_Millipore_ICC                    285 non-null    float64
#  19  MAP2_Santa_Cruz                     285 non-null    float64
#  20  participant_id                      289 non-null    object
#  21  GUID                                0 non-null      object
#  22  visit_name                          289 non-null    object
#  23  visit_month                         289 non-null    float64
#  24  age_at_baseline                     289 non-null    float64
#  25  sex                                 289 non-null    object
#  26  ethnicity_x                         289 non-null    object
#  27  race                                289 non-null    object
#  28  education_level_years               289 non-null    object
#  29  diagnosis_at_baseline               289 non-null    object
#  30  diagnosis_latest                    289 non-null    object
#  31  case_control_other_at_baseline      289 non-null    object
#  32  case_control_other_latest           289 non-null    object
#  33  study_arm                           289 non-null    object
#  34  prodromal_category                  289 non-null    object
#  35  Recruitment                         288 non-null    object
#  36  wgsid                               289 non-null    object
#  37  PATNO                               292 non-null    float64
#  38  RECRUIT                             292 non-null    object
#  39  YEARSEDUC                           292 non-null    float64
#  40  FAMILY_HISTORY                      292 non-null    float64
#  41  DX_INIT                             292 non-null    object
#  42  DIAG                                292 non-null    object
#  43  AGE_enroll                          292 non-null    float64
#  44  AGE_ONSET                           166 non-null    float64
#  45  BIRTHDT                             292 non-null    float64
#  46  RECRUITMENT_CAT                     292 non-null    object
#  47  IMAGING_CAT                         292 non-null    object
#  48  ENROLL_CAT                          292 non-null    object
#  49  DESCRP_CAT                          292 non-null    object
#  50  genetic_sex                         292 non-null    float64
#  51  pheno                               292 non-null    object
#  52  Barcode_LNG                         292 non-null    object
#  53  Barcode_DZNE                        292 non-null    object
#  54  Alternate MRN                       292 non-null    object
#  55  IID                                 292 non-null    object
#  56  mutation                            292 non-null    object
#  57  ethnicity_y                         292 non-null    object
#  58  Relatives                           292 non-null    object
#  59  exclude                             292 non-null    object
#  60  FID                                 292 non-null    object
#  61  CNT                                 292 non-null    float64
#  62  CNT2                                292 non-null    float64
#  63  SCORE                               292 non-null    float64
#  64  SCORE_no_GBA                        292 non-null    float64
#  65  GROUP                               292 non-null    object
#  66  PC1                                 289 non-null    float64
#  67  PC2                                 289 non-null    float64
#  68  PC3                                 289 non-null    float64
#  69  PC4                                 289 non-null    float64
#  70  PC5                                 289 non-null    float64
#  71  PC6                                 289 non-null    float64
#  72  PC7                                 289 non-null    float64
#  73  PC8                                 289 non-null    float64
#  74  PC9                                 289 non-null    float64
#  75  PC10                                289 non-null    float64
#  76  PC11                                289 non-null    float64
#  77  PC12                                289 non-null    float64
#  78  PC13                                289 non-null    float64
#  79  PC14                                289 non-null    float64
#  80  PC15                                289 non-null    float64
#  81  PC16                                289 non-null    float64
#  82  PC17                                289 non-null    float64
#  83  PC18                                289 non-null    float64
#  84  PC19                                289 non-null    float64
#  85  PC20                                289 non-null    float64
#  86  meancnt                             0 non-null      float64
#  87  DopaminergicNeurons                 298 non-null    float64
#  88  EarlyneuronProgenitor               298 non-null    float64
#  89  ImmatureDopaminergicNeurons         298 non-null    float64
#  90  ProliferatingFloorPlateProgenitors  298 non-null    float64
#  91  LateneuronProgenitor                298 non-null    float64
#  92  Ependymal-likeCells                 298 non-null    float64
#  93  Neuroepithelial-likeCells           298 non-null    float64
# dtypes: float64(47), object(47)
# memory usage: 221.2+ KB
# None

# %% [markdown]
# #### get rid of the columns that have single values or a lot missingness

# %%
cols_to_drop = []
for this_col in info_df.columns:
    drop_col = False
    try:
        percent_miss = info_df[this_col].isna().sum()/info_df.shape[0]
        if percent_miss > max_cov_missing_rate:
            drop_col = True
        else:
            total_unique = len(info_df[this_col].unique())
            if total_unique == 1 or (total_unique == info_df.shape[0] 
                                     and info_df[this_col].dtype == 'object'):
                drop_col = True
    except:
        drop_col = True

    if drop_col:
        cols_to_drop.append(this_col)

        
print(cols_to_drop)
# Out:
# ['assay', 'version', 'GUID', 'meancnt']

# %%
info_df['ethnicity_y'].value_counts()
# Out:
# European    292
# Name: ethnicity_y, dtype: int64

# %%
# fix those assay metrics colnames that have preceeding spaces
cols_new_names = {' Proper Pairs': 'ProperPairs', ' Assigned': 'Assigned', 
                  'M Assigned': 'MAssigned', ' Aligned': 'Aligned', 
                  'M Aligned': 'MAligned', ' Aligned.1': 'Aligned.1', 
                  'M Aligned.1': 'MAligned.1', ' Dups': 'Dups', ' GC': 'GC',
                  'M Seqs': 'MSeqs'}
info_df.rename(columns=cols_new_names, inplace=True)

# %%
# see if sample without WGS is still there, ie won't have genetic PCs computed
info_df.loc[info_df['wgsid'].isna()]

# %%
# which samples are missing cell fractions
print(info_df.loc[info_df['DopaminergicNeurons'].isna()].shape)
display(info_df.loc[info_df['DopaminergicNeurons'].isna()])
print(info_df.loc[info_df['DopaminergicNeurons'].isna()].index)
# Out:
# (0, 94)
# Empty DataFrame
# Columns: [assay, sampleid, cdi, day, version, Batch, PPMI_ID, DZNE_Barcode, DZNE_ID, Culture_Media_iPSC, Growth_iPSC, Spontaneous_differentiation, Mychoplasma_Test, Differentiation_Start, TH_SCRN, MAP2_SCRN, TH_Pel-Freez_ICC, MAP2_Santa_Cruz_ICC, TH_Millipore_ICC, MAP2_Santa_Cruz, participant_id, GUID, visit_name, visit_month, age_at_baseline, sex, ethnicity_x, race, education_level_years, diagnosis_at_baseline, diagnosis_latest, case_control_other_at_baseline, case_control_other_latest, study_arm, prodromal_category, Recruitment, wgsid, PATNO, RECRUIT, YEARSEDUC, FAMILY_HISTORY, DX_INIT, DIAG, AGE_enroll, AGE_ONSET, BIRTHDT, RECRUITMENT_CAT, IMAGING_CAT, ENROLL_CAT, DESCRP_CAT, genetic_sex, pheno, Barcode_LNG, Barcode_DZNE, Alternate MRN, IID, mutation, ethnicity_y, Relatives, exclude, FID, CNT, CNT2, SCORE, SCORE_no_GBA, GROUP, PC1, PC2, PC3, PC4, PC5, PC6, PC7, PC8, PC9, PC10, PC11, PC12, PC13, PC14, PC15, PC16, PC17, PC18, PC19, PC20, meancnt, DopaminergicNeurons, EarlyneuronProgenitor, ImmatureDopaminergicNeurons, ProliferatingFloorPlateProgenitors, LateneuronProgenitor, Ependymal-likeCells, Neuroepithelial-likeCells]
# Index: []
#
# [0 rows x 94 columns]
# Index([], dtype='object', name='assayid')

# %% [markdown]
# #### for specific later cell-type specific analyses combine DopaminergicNeurons and ImmatureDopaminergicNeurons into DAn

# %%
info_df['DAn'] = info_df['DopaminergicNeurons'] + info_df['ImmatureDopaminergicNeurons']
print(info_df[['DAn', 'DopaminergicNeurons', 'ImmatureDopaminergicNeurons']].describe())
# display(info_df.sample(5))
# Out:
#               DAn  DopaminergicNeurons  ImmatureDopaminergicNeurons
# count  298.000000           298.000000                   298.000000
# mean     0.216796             0.146255                     0.070541
# std      0.240604             0.178208                     0.091670
# min      0.003692             0.002964                     0.000682
# 25%      0.008678             0.006600                     0.002443
# 50%      0.112807             0.062457                     0.037621
# 75%      0.394260             0.248180                     0.099077
# max      0.941889             0.842768                     0.500590

# %% [markdown]
# #### if those columns look useless drop

# %%
info_df.drop(columns=cols_to_drop, inplace=True)
print(info_df.shape)
# Out:
# (298, 91)

# %% [markdown]
# #### save the complete covariates file

# %%
info_df.to_csv(assay_covs_files)

# %% [markdown]
# #### take a look to see how corrlated or predictive covariates are and visualize

# %% [markdown]
# #### use Predictive Power Score to see what is associated with predict cell fractions

# %%
cfrac_covs = []
for cell_type in cfracs_df.columns:
    print(cell_type)
    # remove the other cell types
    other_cells = set(cfracs_df.columns) - set([cell_type])
    this_df = info_df.drop(columns=other_cells)
    predictors_df = pps.predictors(this_df, cell_type)
    # drop anything that has ppscore of zero
    predictors_df = predictors_df.loc[predictors_df['ppscore'] > 0]
    display(predictors_df)
    cfrac_covs.extend(list(predictors_df['x'].values))

print(cfrac_covs)

# check other cell type related covariates for ther predictorsTH_SCRN
temp_other_covs = ['TH_SCRN', 'MAP2_SCRN']
for this_cov in temp_other_covs:
    print(this_cov)
    predictors_df = pps.predictors(info_df, this_cov)
    # drop anything that has ppscore of zero
    predictors_df = predictors_df.loc[predictors_df['ppscore'] > 0]
    display(predictors_df)
# Out:
# DopaminergicNeurons
#      x                    y   ppscore        case  is_valid_score  \
# 0  DAn  DopaminergicNeurons  0.660659  regression            True
# 1  day  DopaminergicNeurons  0.328303  regression            True
#
#                 metric  baseline_score  model_score                    model
# 0  mean absolute error        0.129042     0.043789  DecisionTreeRegressor()
# 1  mean absolute error        0.129042     0.086677  DecisionTreeRegressor()
# EarlyneuronProgenitor
#      x                      y   ppscore        case  is_valid_score  \
# 0  day  EarlyneuronProgenitor  0.360437  regression            True
# 1  DAn  EarlyneuronProgenitor  0.165165  regression            True
#
#                 metric  baseline_score  model_score                    model
# 0  mean absolute error        0.076376     0.048847  DecisionTreeRegressor()
# 1  mean absolute error        0.076376     0.063761  DecisionTreeRegressor()
# ImmatureDopaminergicNeurons
#      x                            y   ppscore        case  is_valid_score  \
# 0  DAn  ImmatureDopaminergicNeurons  0.295338  regression            True
# 1  day  ImmatureDopaminergicNeurons  0.254840  regression            True
#
#                 metric  baseline_score  model_score                    model
# 0  mean absolute error        0.062102     0.043761  DecisionTreeRegressor()
# 1  mean absolute error        0.062102     0.046276  DecisionTreeRegressor()
# ProliferatingFloorPlateProgenitors
#      x                                   y   ppscore        case  \
# 0  day  ProliferatingFloorPlateProgenitors  0.897510  regression
# 1  DAn  ProliferatingFloorPlateProgenitors  0.814717  regression
#
#    is_valid_score               metric  baseline_score  model_score  \
# 0            True  mean absolute error        0.309593     0.031730
# 1            True  mean absolute error        0.309593     0.057362
#
#                      model
# 0  DecisionTreeRegressor()
# 1  DecisionTreeRegressor()
# LateneuronProgenitor
#      x                     y   ppscore        case  is_valid_score  \
# 0  DAn  LateneuronProgenitor  0.578270  regression            True
# 1  day  LateneuronProgenitor  0.338047  regression            True
#
#                 metric  baseline_score  model_score                    model
# 0  mean absolute error        0.196903     0.083040  DecisionTreeRegressor()
# 1  mean absolute error        0.196903     0.130341  DecisionTreeRegressor()
# Ependymal-likeCells
#      x                    y   ppscore        case  is_valid_score  \
# 0  day  Ependymal-likeCells  0.496223  regression            True
# 1  DAn  Ependymal-likeCells  0.431398  regression            True
#
#                 metric  baseline_score  model_score                    model
# 0  mean absolute error        0.006485     0.003267  DecisionTreeRegressor()
# 1  mean absolute error        0.006485     0.003687  DecisionTreeRegressor()
# Neuroepithelial-likeCells
# Empty DataFrame
# Columns: [x, y, ppscore, case, is_valid_score, metric, baseline_score, model_score, model]
# Index: []
# ['DAn', 'day', 'day', 'DAn', 'DAn', 'day', 'day', 'DAn', 'DAn', 'day', 'day', 'DAn']
# TH_SCRN
#                         x        y   ppscore        case  is_valid_score  \
# 0                    PC17  TH_SCRN  0.985721  regression            True
# 1                    PC14  TH_SCRN  0.985183  regression            True
# 2                     PC5  TH_SCRN  0.975465  regression            True
# 3                    PC15  TH_SCRN  0.975436  regression            True
# 4                     PC1  TH_SCRN  0.975193  regression            True
# 5                     PC9  TH_SCRN  0.975177  regression            True
# 6                     PC8  TH_SCRN  0.970257  regression            True
# 7                     PC2  TH_SCRN  0.969387  regression            True
# 8                    PC13  TH_SCRN  0.967215  regression            True
# 9                     PC6  TH_SCRN  0.967041  regression            True
# 10                    PC4  TH_SCRN  0.962986  regression            True
# 11         participant_id  TH_SCRN  0.962642  regression            True
# 12                  wgsid  TH_SCRN  0.962642  regression            True
# 13                   PC18  TH_SCRN  0.962274  regression            True
# 14                   PC10  TH_SCRN  0.962210  regression            True
# 15                    PC3  TH_SCRN  0.960441  regression            True
# 16                   PC20  TH_SCRN  0.953721  regression            True
# 17                   PC19  TH_SCRN  0.951597  regression            True
# 18                   PC11  TH_SCRN  0.951067  regression            True
# 19                  PATNO  TH_SCRN  0.950095  regression            True
# 20                   PC16  TH_SCRN  0.945576  regression            True
# 21                    PC7  TH_SCRN  0.944815  regression            True
# 22                  SCORE  TH_SCRN  0.943501  regression            True
# 23               sampleid  TH_SCRN  0.931787  regression            True
# 24                    cdi  TH_SCRN  0.931787  regression            True
# 25                PPMI_ID  TH_SCRN  0.931787  regression            True
# 26           DZNE_Barcode  TH_SCRN  0.931787  regression            True
# 27                DZNE_ID  TH_SCRN  0.931787  regression            True
# 28                    IID  TH_SCRN  0.931787  regression            True
# 29                    FID  TH_SCRN  0.931787  regression            True
# 30           SCORE_no_GBA  TH_SCRN  0.929411  regression            True
# 31                   PC12  TH_SCRN  0.911079  regression            True
# 32        MAP2_Santa_Cruz  TH_SCRN  0.890106  regression            True
# 33             AGE_enroll  TH_SCRN  0.883277  regression            True
# 34       TH_Millipore_ICC  TH_SCRN  0.850086  regression            True
# 35       TH_Pel-Freez_ICC  TH_SCRN  0.848664  regression            True
# 36              MAP2_SCRN  TH_SCRN  0.809193  regression            True
# 37              AGE_ONSET  TH_SCRN  0.806677  regression            True
# 38    MAP2_Santa_Cruz_ICC  TH_SCRN  0.755195  regression            True
# 39            Barcode_LNG  TH_SCRN  0.718352  regression            True
# 40           Barcode_DZNE  TH_SCRN  0.718352  regression            True
# 41          Alternate MRN  TH_SCRN  0.718352  regression            True
# 42        age_at_baseline  TH_SCRN  0.325742  regression            True
# 43  Differentiation_Start  TH_SCRN  0.207421  regression            True
# 44                  Batch  TH_SCRN  0.169462  regression            True
# 45                   DIAG  TH_SCRN  0.147795  regression            True
# 46                BIRTHDT  TH_SCRN  0.110559  regression            True
# 47              YEARSEDUC  TH_SCRN  0.097925  regression            True
# 48                   CNT2  TH_SCRN  0.057684  regression            True
# 49              Relatives  TH_SCRN  0.010630  regression            True
# 50                RECRUIT  TH_SCRN  0.008307  regression            True
# 51            Recruitment  TH_SCRN  0.007780  regression            True
# 52              study_arm  TH_SCRN  0.007780  regression            True
# 53            IMAGING_CAT  TH_SCRN  0.005686  regression            True
# 54             ENROLL_CAT  TH_SCRN  0.005686  regression            True
# 55                   race  TH_SCRN  0.000083  regression            True
#
#                  metric  baseline_score  model_score                    model
# 0   mean absolute error        4.901220     0.069983  DecisionTreeRegressor()
# 1   mean absolute error        4.901220     0.072620  DecisionTreeRegressor()
# 2   mean absolute error        4.901220     0.120254  DecisionTreeRegressor()
# 3   mean absolute error        4.901220     0.120393  DecisionTreeRegressor()
# 4   mean absolute error        4.901220     0.121582  DecisionTreeRegressor()
# 5   mean absolute error        4.901220     0.121662  DecisionTreeRegressor()
# 6   mean absolute error        4.901220     0.145776  DecisionTreeRegressor()
# 7   mean absolute error        4.901220     0.150040  DecisionTreeRegressor()
# 8   mean absolute error        4.901220     0.160689  DecisionTreeRegressor()
# 9   mean absolute error        4.901220     0.161542  DecisionTreeRegressor()
# 10  mean absolute error        4.901220     0.181412  DecisionTreeRegressor()
# 11  mean absolute error        4.901220     0.183098  DecisionTreeRegressor()
# 12  mean absolute error        4.901220     0.183098  DecisionTreeRegressor()
# 13  mean absolute error        4.901220     0.184902  DecisionTreeRegressor()
# 14  mean absolute error        4.901220     0.185219  DecisionTreeRegressor()
# 15  mean absolute error        4.901220     0.193886  DecisionTreeRegressor()
# 16  mean absolute error        4.901220     0.226824  DecisionTreeRegressor()
# 17  mean absolute error        4.901220     0.237236  DecisionTreeRegressor()
# 18  mean absolute error        4.901220     0.239833  DecisionTreeRegressor()
# 19  mean absolute error        4.979518     0.248502  DecisionTreeRegressor()
# 20  mean absolute error        4.901220     0.266744  DecisionTreeRegressor()
# 21  mean absolute error        4.901220     0.270472  DecisionTreeRegressor()
# 22  mean absolute error        4.979518     0.281336  DecisionTreeRegressor()
# 23  mean absolute error        4.979518     0.339670  DecisionTreeRegressor()
# 24  mean absolute error        4.979518     0.339670  DecisionTreeRegressor()
# 25  mean absolute error        4.979518     0.339670  DecisionTreeRegressor()
# 26  mean absolute error        4.979518     0.339670  DecisionTreeRegressor()
# 27  mean absolute error        4.979518     0.339670  DecisionTreeRegressor()
# 28  mean absolute error        4.979518     0.339670  DecisionTreeRegressor()
# 29  mean absolute error        4.979518     0.339670  DecisionTreeRegressor()
# 30  mean absolute error        4.979518     0.351498  DecisionTreeRegressor()
# 31  mean absolute error        4.901220     0.435821  DecisionTreeRegressor()
# 32  mean absolute error        4.975309     0.546756  DecisionTreeRegressor()
# 33  mean absolute error        4.979518     0.581226  DecisionTreeRegressor()
# 34  mean absolute error        4.975309     0.745869  DecisionTreeRegressor()
# 35  mean absolute error        4.975309     0.752945  DecisionTreeRegressor()
# 36  mean absolute error        4.979518     0.950127  DecisionTreeRegressor()
# 37  mean absolute error        4.220423     0.815907  DecisionTreeRegressor()
# 38  mean absolute error        4.975309     1.217982  DecisionTreeRegressor()
# 39  mean absolute error        4.979518     1.402473  DecisionTreeRegressor()
# 40  mean absolute error        4.979518     1.402473  DecisionTreeRegressor()
# 41  mean absolute error        4.979518     1.402473  DecisionTreeRegressor()
# 42  mean absolute error        4.901220     3.304687  DecisionTreeRegressor()
# 43  mean absolute error        4.979518     3.946660  DecisionTreeRegressor()
# 44  mean absolute error        4.979518     4.135681  DecisionTreeRegressor()
# 45  mean absolute error        4.979518     4.243571  DecisionTreeRegressor()
# 46  mean absolute error        4.979518     4.428985  DecisionTreeRegressor()
# 47  mean absolute error        4.979518     4.491901  DecisionTreeRegressor()
# 48  mean absolute error        4.979518     4.692279  DecisionTreeRegressor()
# 49  mean absolute error        4.979518     4.926584  DecisionTreeRegressor()
# 50  mean absolute error        4.979518     4.938155  DecisionTreeRegressor()
# 51  mean absolute error        4.901220     4.863087  DecisionTreeRegressor()
# 52  mean absolute error        4.901220     4.863087  DecisionTreeRegressor()
# 53  mean absolute error        4.979518     4.951206  DecisionTreeRegressor()
# 54  mean absolute error        4.979518     4.951206  DecisionTreeRegressor()
# 55  mean absolute error        4.901220     4.900815  DecisionTreeRegressor()
# MAP2_SCRN
#                                  x          y   ppscore        case  \
# 0                              PC6  MAP2_SCRN  0.995744  regression
# 1                             PC10  MAP2_SCRN  0.993900  regression
# 2                             PC15  MAP2_SCRN  0.987801  regression
# 3                             PC18  MAP2_SCRN  0.980564  regression
# 4                   participant_id  MAP2_SCRN  0.980332  regression
# ..                             ...        ...       ...         ...
# 61                  FAMILY_HISTORY  MAP2_SCRN  0.021798  regression
# 62       case_control_other_latest  MAP2_SCRN  0.019899  regression
# 63  case_control_other_at_baseline  MAP2_SCRN  0.018392  regression
# 64                       YEARSEDUC  MAP2_SCRN  0.017845  regression
# 65                     ethnicity_x  MAP2_SCRN  0.004869  regression
#
#     is_valid_score               metric  baseline_score  model_score  \
# 0             True  mean absolute error        9.152033     0.038948
# 1             True  mean absolute error        9.152033     0.055824
# 2             True  mean absolute error        9.152033     0.111647
# 3             True  mean absolute error        9.152033     0.177882
# 4             True  mean absolute error        9.152033     0.180004
# ..             ...                  ...             ...          ...
# 61            True  mean absolute error        9.206024     9.005354
# 62            True  mean absolute error        9.152033     8.969921
# 63            True  mean absolute error        9.152033     8.983710
# 64            True  mean absolute error        9.206024     9.041743
# 65            True  mean absolute error        9.152033     9.107467
#
#                       model
# 0   DecisionTreeRegressor()
# 1   DecisionTreeRegressor()
# 2   DecisionTreeRegressor()
# 3   DecisionTreeRegressor()
# 4   DecisionTreeRegressor()
# ..                      ...
# 61  DecisionTreeRegressor()
# 62  DecisionTreeRegressor()
# 63  DecisionTreeRegressor()
# 64  DecisionTreeRegressor()
# 65  DecisionTreeRegressor()
#
# [66 rows x 9 columns]

# %%
matrix_df = pps.matrix(info_df[list(set(cfrac_covs) | set(cfracs_df.columns))])
matrix_df = matrix_df.loc[matrix_df['ppscore'] > 0]
print(matrix_df.shape)

matrix_df['ppscore'] = matrix_df['ppscore'].round(2)
plot_matrix_df = matrix_df[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
print(plot_matrix_df.shape)
display(plot_matrix_df)
# Out:
# (66, 9)
# (9, 9)
# x                                    DAn  DopaminergicNeurons  \
# y
# DAn                                 1.00                 0.75
# DopaminergicNeurons                 0.66                 1.00
# EarlyneuronProgenitor               0.17                 0.09
# Ependymal-likeCells                 0.43                 0.21
# ImmatureDopaminergicNeurons         0.30                 0.23
# LateneuronProgenitor                0.58                 0.52
# Neuroepithelial-likeCells            NaN                  NaN
# ProliferatingFloorPlateProgenitors  0.81                 0.82
# day                                 0.55                 0.56
#
# x                                   EarlyneuronProgenitor  \
# y
# DAn                                                  0.16
# DopaminergicNeurons                                  0.08
# EarlyneuronProgenitor                                1.00
# Ependymal-likeCells                                  0.13
# ImmatureDopaminergicNeurons                          0.01
# LateneuronProgenitor                                 0.09
# Neuroepithelial-likeCells                             NaN
# ProliferatingFloorPlateProgenitors                   0.83
# day                                                  0.58
#
# x                                   Ependymal-likeCells  \
# y
# DAn                                                0.40
# DopaminergicNeurons                                0.17
# EarlyneuronProgenitor                              0.18
# Ependymal-likeCells                                1.00
# ImmatureDopaminergicNeurons                        0.29
# LateneuronProgenitor                               0.37
# Neuroepithelial-likeCells                           NaN
# ProliferatingFloorPlateProgenitors                 0.83
# day                                                0.65
#
# x                                   ImmatureDopaminergicNeurons  \
# y
# DAn                                                        0.49
# DopaminergicNeurons                                        0.25
# EarlyneuronProgenitor                                      0.04
# Ependymal-likeCells                                        0.40
# ImmatureDopaminergicNeurons                                1.00
# LateneuronProgenitor                                       0.44
# Neuroepithelial-likeCells                                   NaN
# ProliferatingFloorPlateProgenitors                         0.83
# day                                                        0.57
#
# x                                   LateneuronProgenitor  \
# y
# DAn                                                 0.53
# DopaminergicNeurons                                 0.36
# EarlyneuronProgenitor                               0.24
# Ependymal-likeCells                                 0.27
# ImmatureDopaminergicNeurons                         0.26
# LateneuronProgenitor                                1.00
# Neuroepithelial-likeCells                            NaN
# ProliferatingFloorPlateProgenitors                  0.76
# day                                                 0.53
#
# x                                   Neuroepithelial-likeCells  \
# y
# DAn                                                       NaN
# DopaminergicNeurons                                       NaN
# EarlyneuronProgenitor                                     NaN
# Ependymal-likeCells                                       NaN
# ImmatureDopaminergicNeurons                               NaN
# LateneuronProgenitor                                      NaN
# Neuroepithelial-likeCells                                1.00
# ProliferatingFloorPlateProgenitors                       0.12
# day                                                      0.19
#
# x                                   ProliferatingFloorPlateProgenitors   day
# y
# DAn                                                               0.27  0.40
# DopaminergicNeurons                                               0.19  0.33
# EarlyneuronProgenitor                                             0.16  0.36
# Ependymal-likeCells                                               0.22  0.50
# ImmatureDopaminergicNeurons                                        NaN  0.25
# LateneuronProgenitor                                              0.12  0.34
# Neuroepithelial-likeCells                                          NaN   NaN
# ProliferatingFloorPlateProgenitors                                1.00  0.90
# day                                                               0.77  1.00

# %%
plt.figure(figsize=(16,16)) 
sns.heatmap(plot_matrix_df, vmin=0, vmax=1, cmap="Blues", linewidths=0.05, 
            annot=True, annot_kws={"fontsize":12})
plt.show()

# %%
temp_df = info_df[list(set(cfrac_covs) | set(cfracs_df.columns))]
cats_df = temp_df.select_dtypes(include=['object'])
print(cats_df.shape)
dums_df = pd.get_dummies(cats_df)
print(dums_df.shape)

covs_df = temp_df.merge(dums_df, how='inner', left_index=True, right_index=True)
print(covs_df.shape)
# Out:
# (298, 1)
# (298, 3)
# (370, 12)

# %%
sns.set()
cor = covs_df.corr(method='pearson')
cor.dropna(how='all', inplace=True)
print(cor.shape)
plt.figure(figsize=(16,16))        
sns.heatmap(cor[(cor > 0.22) | (cor < -0.22)], annot=True, annot_kws={"fontsize":10}, \
            linewidths=0.05)    
plt.show()
# Out:
# (11, 11)

# %%
# a lot of warning can be generated related to number of members and n_splits=4
# so temp supress warnings
warnings.filterwarnings('ignore')

matrix_df = pps.matrix(info_df)
matrix_df = matrix_df.loc[matrix_df['ppscore'] > 0]
print(matrix_df.shape)

default_max_rows = pd.get_option('display.max_rows')
pd.set_option('display.max_rows', 100)
display(matrix_df)
pd.set_option('display.max_rows', default_max_rows)

# restore defaults warning setting
# warnings.filterwarnings('default')
warnings.filterwarnings('once')
# Out:
# (5355, 9)
#              x                                   y   ppscore            case  \
# 0     sampleid                            sampleid  1.000000  predict_itself
# 1     sampleid                                 cdi  0.995449  classification
# 3     sampleid                               Batch  0.886956  classification
# 4     sampleid                             PPMI_ID  0.995370  classification
# 5     sampleid                        DZNE_Barcode  0.995370  classification
# ...        ...                                 ...       ...             ...
# 8275       DAn         ImmatureDopaminergicNeurons  0.295338      regression
# 8276       DAn  ProliferatingFloorPlateProgenitors  0.814717      regression
# 8277       DAn                LateneuronProgenitor  0.578270      regression
# 8278       DAn                 Ependymal-likeCells  0.431398      regression
# 8280       DAn                                 DAn  1.000000  predict_itself
#
#       is_valid_score               metric  baseline_score  model_score  \
# 0               True                 None        0.000000     1.000000
# 1               True          weighted F1        0.023490     0.995556
# 3               True          weighted F1        0.229452     0.912894
# 4               True          weighted F1        0.013699     0.995434
# 5               True          weighted F1        0.013699     0.995434
# ...              ...                  ...             ...          ...
# 8275            True  mean absolute error        0.062102     0.043761
# 8276            True  mean absolute error        0.309593     0.057362
# 8277            True  mean absolute error        0.196903     0.083040
# 8278            True  mean absolute error        0.006485     0.003687
# 8280            True                 None        0.000000     1.000000
#
#                          model
# 0                         None
# 1     DecisionTreeClassifier()
# 3     DecisionTreeClassifier()
# 4     DecisionTreeClassifier()
# 5     DecisionTreeClassifier()
# ...                        ...
# 8275   DecisionTreeRegressor()
# 8276   DecisionTreeRegressor()
# 8277   DecisionTreeRegressor()
# 8278   DecisionTreeRegressor()
# 8280                      None
#
# [5355 rows x 9 columns]

# %%
matrix_df['ppscore'] = matrix_df['ppscore'].round(2)
plot_matrix_df = matrix_df[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
print(plot_matrix_df.shape)
display(plot_matrix_df)
# Out:
# (91, 91)
# x              AGE_ONSET  AGE_enroll  Alternate MRN  BIRTHDT  Barcode_DZNE  \
# y
# AGE_ONSET           1.00        0.99           0.71     0.87          0.71
# AGE_enroll          0.96        1.00           0.72     0.78          0.72
# Alternate MRN       0.94        0.81           1.00     0.22          1.00
# BIRTHDT             0.95        0.90           0.72     1.00          0.72
# Barcode_DZNE        0.94        0.80           1.00     0.22          1.00
# ...                  ...         ...            ...      ...           ...
# sex                 0.80        0.77           0.84     0.44          0.84
# study_arm           0.87        0.74           0.82     0.40          0.82
# visit_month          NaN         NaN            NaN      NaN           NaN
# visit_name           NaN         NaN            NaN      NaN           NaN
# wgsid                NaN        0.81           0.84     0.24          0.84
#
# x              Barcode_LNG  Batch   CNT  CNT2  Culture_Media_iPSC  ...  \
# y                                                                  ...
# AGE_ONSET             0.71   0.02   NaN   NaN                 NaN  ...
# AGE_enroll            0.72   0.03   NaN  0.02                 NaN  ...
# Alternate MRN         1.00   0.10   NaN  0.10                0.08  ...
# BIRTHDT               0.72   0.06   NaN  0.00                 NaN  ...
# Barcode_DZNE          1.00   0.10   NaN  0.10                0.08  ...
# ...                    ...    ...   ...   ...                 ...  ...
# sex                   0.84   0.03   NaN  0.36                0.02  ...
# study_arm             0.82   0.16  0.04  0.25                 NaN  ...
# visit_month            NaN    NaN   NaN   NaN                 NaN  ...
# visit_name             NaN    NaN   NaN   NaN                 NaN  ...
# wgsid                 0.84   0.02   NaN  0.11                 NaN  ...
#
# x              participant_id  pheno  prodromal_category  race  sampleid  \
# y
# AGE_ONSET                0.94    NaN                 NaN   NaN      0.93
# AGE_enroll               0.91    NaN                 NaN   NaN      0.86
# Alternate MRN            0.99   0.00                0.02  0.00      0.99
# BIRTHDT                  0.90    NaN                 NaN   NaN      0.85
# Barcode_DZNE             0.99   0.00                0.02  0.00      0.99
# ...                       ...    ...                 ...   ...       ...
# sex                      0.95   0.33                 NaN  0.01      0.95
# study_arm                0.94   0.38                0.01   NaN      0.94
# visit_month               NaN    NaN                 NaN   NaN       NaN
# visit_name                NaN    NaN                 NaN   NaN       NaN
# wgsid                    1.00   0.01                0.01  0.01      1.00
#
# x               sex  study_arm  visit_month  visit_name  wgsid
# y
# AGE_ONSET       NaN       0.02          NaN         NaN   0.94
# AGE_enroll      NaN       0.00          NaN         NaN   0.91
# Alternate MRN  0.00       0.07          0.0         0.0   0.99
# BIRTHDT         NaN       0.01          NaN         NaN   0.90
# Barcode_DZNE   0.00       0.07          0.0         0.0   0.99
# ...             ...        ...          ...         ...    ...
# sex            1.00       0.43          NaN         NaN   0.95
# study_arm      0.17       1.00          NaN         NaN   0.94
# visit_month     NaN        NaN          1.0         NaN    NaN
# visit_name      NaN        NaN          NaN         1.0    NaN
# wgsid           NaN       0.04          NaN         NaN   1.00
#
# [91 rows x 91 columns]

# %%
# plt.figure(figsize=(24,20)) 
# sns.heatmap(plot_matrix_df, vmin=0, vmax=1, cmap="Blues", linewidths=0.05, 
#             annot=True, annot_kws={"fontsize":10})
# plt.show()

# %%
info_df.select_dtypes(include=['object']).columns
# Out:
# Index(['sampleid', 'cdi', 'day', 'Batch', 'PPMI_ID', 'DZNE_Barcode', 'DZNE_ID',
#        'Culture_Media_iPSC', 'Growth_iPSC', 'Spontaneous_differentiation',
#        'Mychoplasma_Test', 'Differentiation_Start', 'participant_id',
#        'visit_name', 'sex', 'ethnicity_x', 'race', 'education_level_years',
#        'diagnosis_at_baseline', 'diagnosis_latest',
#        'case_control_other_at_baseline', 'case_control_other_latest',
#        'study_arm', 'prodromal_category', 'Recruitment', 'wgsid', 'RECRUIT',
#        'DX_INIT', 'DIAG', 'RECRUITMENT_CAT', 'IMAGING_CAT', 'ENROLL_CAT',
#        'DESCRP_CAT', 'pheno', 'Barcode_LNG', 'Barcode_DZNE', 'Alternate MRN',
#        'IID', 'mutation', 'ethnicity_y', 'Relatives', 'exclude', 'FID',
#        'GROUP'],
#       dtype='object')

# %%
# cats_df = info_df.select_dtypes(include=['object'])
cats_df = info_df[['day', 'Batch', 'Culture_Media_iPSC', 'Growth_iPSC',
                   'Spontaneous_differentiation', 'Differentiation_Start',
                   'visit_name', 'sex', 'ethnicity_x', 'race',
                   'education_level_years', 'diagnosis_at_baseline', 
                   'diagnosis_latest', 'case_control_other_at_baseline', 
                   'case_control_other_latest', 'study_arm', 'prodromal_category', 
                   'Recruitment', 'RECRUIT', 'DX_INIT', 'DIAG', 'RECRUITMENT_CAT', 
                   'IMAGING_CAT', 'ENROLL_CAT', 'DESCRP_CAT', 'pheno',
                   'mutation', 'Relatives', 'GROUP']]
print(cats_df.shape)
dums_df = pd.get_dummies(cats_df)
print(dums_df.shape)

covs_df = info_df.merge(dums_df, how='inner', left_index=True, right_index=True)
print(covs_df.shape)
# Out:
# (298, 29)
# (298, 139)
# (370, 230)

# %%
sns.set()
cor = covs_df.corr(method='pearson')
cor.dropna(how='all', inplace=True)
print(cor.shape)
plt.figure(figsize=(24,20))        
sns.heatmap(cor[(cor > 0.22) | (cor < -0.22)], annot=True, annot_kws={"fontsize":10}, \
            linewidths=0.05)
# sns.heatmap(cor[(cor > 0.1) | (cor < -0.1)], annot=True, annot_kws={"fontsize":12}, \
#             linewidths=0.05)
plt.show()
# Out:
# (185, 186)
