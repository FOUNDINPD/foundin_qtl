# %% [markdown]
# ## Notebook for running Gene Set Enrichment Analysis (GSEA) using gseapy
#
# [gseapy docs](https://gseapy.readthedocs.io/en/latest/index.html)

# %%
# !date
# Out:
# Mon Aug  9 17:35:40 EDT 2021

# %% [markdown]
# #### import libraries and set notebook variables

# %%
import gseapy
# Out:
# Creating directory /home/gibbsr/.config/bioservices

# %%
# this list is just closest gene to IPDGC meta5 GWAS index svariants
gene_list = ['HRNR', 'PMVK', 'KRTCAP2', 'GBAP1', 'ASH1L', 'SEMA4A', 'FCGR2A', 
             'VAMP4', 'NUCKS1', 'RAB29', 'ITPKB', 'SIPA1L2', 'KCNS3', 'KCNIP3', 
             'MAP4K4', 'TMEM163', 'TMEM163', 'STK39', 'SATB1', 'LINC00693', 
             'IP6K2', 'KPNA1', 'MED12L', 'SPTSSB', 'MCCC1', 'GAK', 'TMEM175', 
             'BST1', 'LCORL', 'SCARB2', 'FAM47E', 'FAM47E-STBD1', 'SNCA', 'SNCA', 
             'SNCA', 'SNCA', 'CAMK2D', 'CLCN3', 'ELOVL7', 'PAM', 'ZNF608', 
             'C5orf24', 'LOC100131289', 'TRIM40', 'SLC44A4', 'HLA-DRB5', 'RIMS1', 
             'FYN', 'RPS12', 'GPNMB', 'GS1-124K5.11', 'CTSB', 'FGF20', 'BIN3', 
             'FAM49B', 'SH3GL2', 'SH3GL2', 'UBAP2', 'ITGA8', 'GBF1', 'BAG3', 
             'INPP5F', 'RNF141', 'DLG2', 'IGSF9B', 'FGD4', 'PKP2', 'ALG10', 
             'ALG10', 'LRRK2', 'LRRK2', 'LRRK2', 'LRRK2', 'CNTN1', 'CNTN1', 
             'CNTN1', 'CNTN1', 'PDZRN4', 'GXYLT1', 'GXYLT1', 'SCAF11', 'HIP1R', 
             'FBRSL1', 'CAB39L', 'MBNL2', 'MIPOL1', 'GCH1', 'RPS6KL1', 'GALC', 
             'VPS13C', 'SYT17', 'CD19', 'SETD1A', 'NOD2', 'CASC16', 'CHD9', 'CNOT1', 
             'CHRNB1', 'RETREG3', 'UBTF', 'FAM171A2', 'MAP3K14', 'CRHR1', 'CRHR1', 
             'CRHR1', 'MAPT-AS1', 'KANSL1', 'NSF', 'WNT3', 'BRIP1', 'DNAH17', 
             'ASXL3', 'RIT2', 'MEX3C', 'SPPL2B', 'DDRGK1', 'CRLS1', 'DYRK1A']
# gene_list = ['EIF3KP1', 'KLHL7-DT', 'GDPD3', 'ITGAL', 'LENEP', 'TRIM72', 
#              'MAPT', 'ZSCAN9', 'UBAP1', 'PHF24']

# %%
#Available databases : ‘Human’, ‘Mouse’, ‘Yeast’, ‘Fly’, ‘Fish’, ‘Worm’ 
gene_set_names = gseapy.get_library_name(database='Human')
# print(gene_set_names)

# %%
gene_set = 'GO_Biological_Process_2021'
enr_res = gseapy.enrichr(gene_list=gene_list,
                         organism='Human',
                         gene_sets=gene_set,
                         description='pathway',
                         cutoff = 0.5)
print(enr_res.results.shape)
display(enr_res.results.head())
gseapy.barplot(enr_res.res2d,title=gene_set)
# Out:
# (1180, 10)
#                      Gene_set  \
# 0  GO_Biological_Process_2021
# 1  GO_Biological_Process_2021
# 2  GO_Biological_Process_2021
# 3  GO_Biological_Process_2021
# 4  GO_Biological_Process_2021
#
#                                                 Term Overlap       P-value  \
# 0  positive regulation of receptor recycling (GO:...    4/10  1.360186e-07
# 1      positive regulation of signaling (GO:0023056)    5/38  1.440429e-06
# 2      regulation of receptor recycling (GO:0001919)    4/17  1.499404e-06
# 3        cellular response to metal ion (GO:0071248)   6/131  5.984697e-05
# 4  protein localization to endoplasmic reticulum ...    3/16  7.074811e-05
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.000161            0                     0  133.946128
# 1          0.000590            0                     0   30.711194
# 2          0.000590            0                     0   61.799534
# 3          0.016164            0                     0    9.784082
# 4          0.016164            0                     0   45.886154
#
#    Combined Score                               Genes
# 0     2117.751841               NSF;INPP5F;RAB29;SNCA
# 1      413.083048         NSF;RIMS1;INPP5F;RAB29;SNCA
# 2      828.759098               NSF;INPP5F;RAB29;SNCA
# 3       95.137676  ITPKB;CAMK2D;DLG2;LRRK2;SNCA;SYT17
# 4      438.505740                   DDRGK1;LRRK2;GBF1

# %%
gene_set = 'GO_Cellular_Component_2021'
enr_res = gseapy.enrichr(gene_list=gene_list,
                         organism='Human',
                         gene_sets=gene_set,
                         description='pathway',
                         cutoff = 0.5)
print(enr_res.results.shape)
display(enr_res.results.head())
gseapy.barplot(enr_res.res2d,title=gene_set)
# Out:
# (143, 10)
#                      Gene_set                                            Term  \
# 0  GO_Cellular_Component_2021                           lysosome (GO:0005764)
# 1  GO_Cellular_Component_2021                  endocytic vesicle (GO:0030139)
# 2  GO_Cellular_Component_2021  clathrin-coated endocytic vesicle (GO:0045334)
# 3  GO_Cellular_Component_2021                  neuron projection (GO:0043005)
# 4  GO_Cellular_Component_2021         endocytic vesicle membrane (GO:0030666)
#
#   Overlap   P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0  11/477  0.000035          0.003705            0                     0
# 1   7/189  0.000056          0.003705            0                     0
# 2    5/85  0.000078          0.003705            0                     0
# 3  11/556  0.000137          0.004807            0                     0
# 4   6/158  0.000168          0.004807            0                     0
#
#    Odds Ratio  Combined Score  \
# 0    4.985562       51.145706
# 1    7.898638       77.394086
# 2   12.638393      119.588248
# 3    4.245552       37.752173
# 4    8.035133       69.833226
#
#                                                Genes
# 0  NSF;GALC;SCARB2;HLA-DRB5;SPPL2B;LRRK2;VAMP4;CL...
# 1      SCARB2;HLA-DRB5;CAMK2D;INPP5F;NOD2;CLCN3;WNT3
# 2                SCARB2;HLA-DRB5;INPP5F;VAMP4;SH3GL2
# 3  CHRNB1;CAMK2D;DLG2;RIT2;LRRK2;DYRK1A;FYN;IGSF9...
# 4           SCARB2;HLA-DRB5;CAMK2D;VAMP4;SH3GL2;WNT3

# %%
gene_set = 'WikiPathways_2019_Human'
enr_res = gseapy.enrichr(gene_list=gene_list,
                         organism='Human',
                         gene_sets=gene_set,
                         description='pathway',
                         cutoff = 0.5)
print(enr_res.results.shape)
display(enr_res.results.head())
gseapy.barplot(enr_res.res2d,title=gene_set)
# Out:
# (93, 10)
#                   Gene_set                                               Term  \
# 0  WikiPathways_2019_Human  T-Cell Receptor and Co-stimulatory Signaling W...
# 1  WikiPathways_2019_Human                  Parkinsons Disease Pathway WP2371
# 2  WikiPathways_2019_Human                    Synaptic Vesicle Pathway WP2267
# 3  WikiPathways_2019_Human                 Ebola Virus Pathway on Host WP4217
# 4  WikiPathways_2019_Human               Cardiac Hypertrophic Response WP2795
#
#   Overlap   P-value  Adjusted P-value  Old P-value  Old Adjusted P-value  \
# 0    2/29  0.009740          0.304554            0                     0
# 1    2/38  0.016367          0.304554            0                     0
# 2    2/51  0.028432          0.304554            0                     0
# 3   3/129  0.029068          0.304554            0                     0
# 4    2/55  0.032680          0.304554            0                     0
#
#    Odds Ratio  Combined Score                Genes
# 0   14.572791       67.493647           DYRK1A;FYN
# 1   10.924642       44.927206           LRRK2;SNCA
# 2    8.021014       28.556734            NSF;RIMS1
# 3    4.707381       16.655252  HLA-DRB5;KPNA1;CTSB
# 4    7.414160       25.363790       CAMK2D;MAP3K14
# 'Warning: No enrich terms using library WikiPathways_2019_Human when cutoff = 0.05'

# %%
gene_set = 'OMIM_Disease'
enr_res = gseapy.enrichr(gene_list=gene_list,
                         organism='Human',
                         gene_sets=gene_set,
                         description='pathway',
                         cutoff = 0.5)
print(enr_res.results.shape)
display(enr_res.results.head())
gseapy.barplot(enr_res.res2d,title=gene_set)
# Out:
# (12, 10)
#        Gene_set                                        Term Overlap   P-value  \
# 0  OMIM_Disease                           parkinson disease    3/22  0.000190
# 1  OMIM_Disease                          cone-rod dystrophy    2/15  0.002640
# 2  OMIM_Disease                            long qt syndrome    1/12  0.060095
# 3  OMIM_Disease                                    dementia    1/12  0.060095
# 4  OMIM_Disease  arrhythmogenic right ventricular dysplasia    1/13  0.064938
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.002283            0                     0   31.386316
# 1          0.015839            0                     0   30.287890
# 2          0.129877            0                     0   17.723708
# 3          0.129877            0                     0   17.723708
# 4          0.129877            0                     0   16.245915
#
#    Combined Score             Genes
# 0      268.894308  LRRK2;FGF20;SNCA
# 1      179.819922      SEMA4A;RIMS1
# 2       49.836022             ALG10
# 3       49.836022              SNCA
# 4       44.421460              PKP2

# %% [markdown]
# #### we can also probably use this to ID cell clusters
# maybe based on CellMarker_Augmented_2021 or Allen_Brain_Atlas_10x_scRNA_2021

# %%
# Astrocyte gene marker list
# gene_list = ['SLC1A3', 'GFAP', 'APOE', 'SLC1A2', 'SLC14A1', 'CPE', 'CLU', 'ALDOC', 'FAM19A1', 'AQP4', 'GJB6']

# %%
gene_set = 'CellMarker_Augmented_2021'
enr_res = gseapy.enrichr(gene_list=gene_list,
                         organism='Human',
                         gene_sets=gene_set,
                         description='pathway',
                         cutoff = 0.5)
print(enr_res.results.shape)
display(enr_res.results.head())
gseapy.barplot(enr_res.res2d,title=gene_set)
# Out:
# (334, 10)
#                     Gene_set                     Term Overlap   P-value  \
# 0  CellMarker_Augmented_2021  Cardiomyocyte:Undefined    4/97  0.001593
# 1  CellMarker_Augmented_2021        B cell:Lymph Node    2/13  0.001974
# 2  CellMarker_Augmented_2021         B cell:Undefined    3/83  0.009047
# 3  CellMarker_Augmented_2021     Neutrophil:Undefined    2/33  0.012499
# 4  CellMarker_Augmented_2021     Macrophage:Undefined    2/33  0.012499
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.244252            0                     0    8.603888
# 1          0.244252            0                     0   35.798380
# 2          0.244252            0                     0    7.431375
# 3          0.244252            0                     0   12.689875
# 4          0.244252            0                     0   12.689875
#
#    Combined Score                     Genes
# 0       55.429577  SCAF11;CHD9;VPS13C;ASH1L
# 1      222.936612               FCGR2A;CD19
# 2       34.966642          BST1;FCGR2A;CD19
# 3       55.608056               BST1;FCGR2A
# 4       55.608056              FCGR2A;GPNMB
# 'Warning: No enrich terms using library CellMarker_Augmented_2021 when cutoff = 0.05'

# %%
gene_set = 'Allen_Brain_Atlas_10x_scRNA_2021'
enr_res = gseapy.enrichr(gene_list=gene_list,
                         organism='Human',
                         gene_sets=gene_set,
                         description='pathway',
                         cutoff = 0.5)
print(enr_res.results.shape)
display(enr_res.results.head())
gseapy.barplot(enr_res.res2d,title=gene_set)
# Out:
# (291, 10)
#                            Gene_set                  Term Overlap   P-value  \
# 0  Allen_Brain_Atlas_10x_scRNA_2021  Mouse 361 Oligo down  16/913  0.000017
# 1  Allen_Brain_Atlas_10x_scRNA_2021  Mouse 356 Astro down  13/617  0.000017
# 2  Allen_Brain_Atlas_10x_scRNA_2021    Mouse 359 OPC down  14/841  0.000103
# 3  Allen_Brain_Atlas_10x_scRNA_2021  Mouse 363 Oligo down  13/784  0.000193
# 4  Allen_Brain_Atlas_10x_scRNA_2021  Mouse 362 Oligo down  13/791  0.000211
#
#    Adjusted P-value  Old P-value  Old Adjusted P-value  Odds Ratio  \
# 0          0.002469            0                     0    3.895488
# 1          0.002469            0                     0    4.613852
# 2          0.010010            0                     0    3.627298
# 3          0.011651            0                     0    3.583196
# 4          0.011651            0                     0    3.549657
#
#    Combined Score                                              Genes
# 0       42.822396  NSF;FAM49B;MBNL2;CHD9;NUCKS1;ASH1L;CLCN3;MED12...
# 1       50.678528  NSF;FAM49B;MBNL2;GBF1;ASH1L;CLCN3;DLG2;KANSL1;...
# 2       33.294486  NSF;FAM49B;MBNL2;CHD9;ASH1L;CLCN3;RIT2;KANSL1;...
# 3       30.643634  NSF;CHD9;NUCKS1;ASH1L;CLCN3;MED12L;DLG2;KANSL1...
# 4       30.049116  NSF;FAM49B;CHD9;NUCKS1;ASH1L;CLCN3;MED12L;RIMS...
